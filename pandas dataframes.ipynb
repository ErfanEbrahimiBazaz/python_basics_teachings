# %%
import os
import pandas as pd
import numpy as np

# %%
fol = os.path.join(os.getcwd(), 'dataset')
file_to_read = os.path.join(os.path.join(os.getcwd(), 'dataset'), 'Heart data.xlsx')

# %%
df = pd.read_excel(file_to_read)

# %%
df.head()
# Out:
#    age  sex  chest pain  blood pressure  cholestoral  blood sugar  \
# 0   63    1           1           145.0        233.0          1.0
# 1   37    1           3           130.0        250.0          0.0
# 2   41    0           2           130.0        204.0          0.0
# 3   56    1           2           120.0        236.0          0.0
# 4   57    0           4           120.0        354.0          0.0
#
#    electrocardiographic  heart rate  exercise induced  depression  slope ca  \
# 0                   2.0       150.0               0.0         2.3    3.0  0
# 1                   0.0       187.0               0.0         3.5    3.0  0
# 2                   2.0       172.0               0.0         1.4    1.0  0
# 3                   0.0       178.0               0.0         0.8    1.0  0
# 4                   0.0       163.0               1.0         0.6    1.0  0
#
#   thal  c
# 0    6  0
# 1    3  0
# 2    3  0
# 3    3  0
# 4    3  0

# %% [markdown]
# ### 1. Filter records with age higher than 70!

# %%
mask = df['age'] > 70
df[mask].head()
# Out:
#      age  sex  chest pain  blood pressure  cholestoral  blood sugar  \
# 25    71    0           2           160.0        302.0          0.0
# 60    71    0           3           110.0        265.0          1.0
# 129   74    0           2           120.0        269.0          0.0
# 144   76    0           3           140.0        197.0          0.0
# 151   71    0           4           112.0        149.0          0.0
#
#      electrocardiographic  heart rate  exercise induced  depression  slope ca  \
# 25                    0.0       162.0               0.0         0.4    1.0  2
# 60                    2.0       130.0               0.0         0.0    1.0  1
# 129                   2.0       121.0               1.0         0.2    1.0  1
# 144                   1.0       116.0               0.0         1.1    2.0  0
# 151                   0.0       125.0               0.0         1.6    2.0  0
#
#     thal  c
# 25     3  0
# 60     3  0
# 129    3  0
# 144    3  0
# 151    3  0

# %% [markdown]
# ### 2. Increase cholestoral of everyone older than 70!

# %%
df.loc[mask, 'cholestoral'] = df.loc[mask, 'cholestoral'] + 10
df[mask].head()
# Out:
#      age  sex  chest pain  blood pressure  cholestoral  blood sugar  \
# 25    71    0           2           160.0        312.0          0.0
# 60    71    0           3           110.0        275.0          1.0
# 129   74    0           2           120.0        279.0          0.0
# 144   76    0           3           140.0        207.0          0.0
# 151   71    0           4           112.0        159.0          0.0
#
#      electrocardiographic  heart rate  exercise induced  depression  slope ca  \
# 25                    0.0       162.0               0.0         0.4    1.0  2
# 60                    2.0       130.0               0.0         0.0    1.0  1
# 129                   2.0       121.0               1.0         0.2    1.0  1
# 144                   1.0       116.0               0.0         1.1    2.0  0
# 151                   0.0       125.0               0.0         1.6    2.0  0
#
#     thal  c
# 25     3  0
# 60     3  0
# 129    3  0
# 144    3  0
# 151    3  0

# %% [markdown]
# ### 3. Increase cholestoral of all men older than 70 by 5 units!

# %%
mask = ( df['age'] > 70) & (df['sex'] == 1)
df.loc[mask, 'cholestoral'] += 5
df[mask]
# Out:
#      age  sex  chest pain  blood pressure  cholestoral  blood sugar  \
# 577   77    1           4           125.0        309.0          0.0
#
#      electrocardiographic  heart rate  exercise induced  depression  slope ca  \
# 577                   2.0       162.0               1.0         0.0    1.0  3
#
#     thal  c
# 577    3  1

# %% [markdown]
# ### Print all columns in dataframe with object type!

# %%
for col in df.columns:
    print(df[col].dtypes)
# Out:
# int64
# int64
# int64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# object
# object
# int64

# %%
for col in df.columns:
    if df[col].dtypes == 'object':
        print(col)
# Out:
# ca
# thal

# %% [markdown]
# #### 2nd solution

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df.columns[df.dtypes=='object']
# Out:
# Index(['ca', 'thal'], dtype='object')

# %% [markdown]
# ### 5. Prevent warnings to show up!

# %%
import warnings
warnings.filterwarnings('ignore')

# warnings.showwarning()

# %% [markdown]
# ### 6. Delete the dataframe and remove it from memory!

# %%
import gc


del df
gc.collect()
# Out:
# 1317

# %% [markdown]
# ### 7. Show all variables in this notebook!

# %%
df = pd.read_excel(file_to_read)

# %%
# %whos
# Out:
# Variable       Type      Data/Info
# ----------------------------------
# col            str       c
# file_to_read   str       E:\Fad\data mining\sem2\p<...>s\dataset\Heart data.xlsx
# fol            str       E:\Fad\data mining\sem2\practices\dataset
# gc             module    <module 'gc' (built-in)>
# mask           Series    0      False\n1      Fals<...>nLength: 597, dtype: bool
# np             module    <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# os             module    <module 'os' from 'C:\\Pr<...>\\Anaconda3\\lib\\os.py'>
# pd             module    <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# warnings       module    <module 'warnings' from '<...>onda3\\lib\\warnings.py'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 597 entries, 0 to 596
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   597 non-null    int64
#  1   sex                   597 non-null    int64
#  2   chest pain            597 non-null    int64
#  3   blood pressure        596 non-null    float64
#  4   cholestoral           574 non-null    float64
#  5   blood sugar           589 non-null    float64
#  6   electrocardiographic  596 non-null    float64
#  7   heart rate            596 non-null    float64
#  8   exercise induced      596 non-null    float64
#  9   depression            597 non-null    float64
#  10  slope                 407 non-null    float64
#  11  ca                    307 non-null    object
#  12  thal                  331 non-null    object
#  13  c                     597 non-null    int64
# dtypes: float64(8), int64(4), object(2)
# memory usage: 65.4+ KB

# %% [markdown]
# ### Timing operations

# %%
# %%time
df2 = df.select_dtypes(include='object')
df2.head()
# Out:
# Wall time: 2.01 ms
#   ca thal
# 0  0    6
# 1  0    3
# 2  0    3
# 3  0    3
# 4  0    3

# %% [markdown]
# ### Dataframe operations

# %%
df.sort_values(['age','chest pain'], ascending=[False, True]).head()
# Out:
#      age  sex  chest pain  blood pressure  cholestoral  blood sugar  \
# 577   77    1           4           125.0        304.0          0.0
# 144   76    0           3           140.0        197.0          0.0
# 129   74    0           2           120.0        269.0          0.0
# 25    71    0           2           160.0        302.0          0.0
# 60    71    0           3           110.0        265.0          1.0
#
#      electrocardiographic  heart rate  exercise induced  depression  slope ca  \
# 577                   2.0       162.0               1.0         0.0    1.0  3
# 144                   1.0       116.0               0.0         1.1    2.0  0
# 129                   2.0       121.0               1.0         0.2    1.0  1
# 25                    0.0       162.0               0.0         0.4    1.0  2
# 60                    2.0       130.0               0.0         0.0    1.0  1
#
#     thal  c
# 577    3  1
# 144    3  0
# 129    3  0
# 25     3  0
# 60     3  0

# %%
df.head(2)
# Out:
#    age  sex  chest pain  blood pressure  cholestoral  blood sugar  \
# 0   63    1           1           145.0        233.0          1.0
# 1   37    1           3           130.0        250.0          0.0
#
#    electrocardiographic  heart rate  exercise induced  depression  slope ca  \
# 0                   2.0       150.0               0.0         2.3    3.0  0
# 1                   0.0       187.0               0.0         3.5    3.0  0
#
#   thal  c
# 0    6  0
# 1    3  0

# %%
df.sort_values(['age','chest pain'], ascending=[False, True],inplace=True)
df.head(2)
# Out:
#      age  sex  chest pain  blood pressure  cholestoral  blood sugar  \
# 577   77    1           4           125.0        304.0          0.0
# 144   76    0           3           140.0        197.0          0.0
#
#      electrocardiographic  heart rate  exercise induced  depression  slope ca  \
# 577                   2.0       162.0               1.0         0.0    1.0  3
# 144                   1.0       116.0               0.0         1.1    2.0  0
#
#     thal  c
# 577    3  1
# 144    3  0

# %% [markdown]
# ### Saving into file

# %%
df.to_excel(r'processed_df.xlsx', index=False, sheet_name = 'dataframe', encoding='utf-8')

# %%
# !dir

# %% [markdown]
# ### Removing a column from dataframe

# %%
df.drop('c', axis=1, inplace=True) # axis=0 for index, 1 for column
df.head()
# Out:
#      age  sex  chest pain  blood pressure  cholestoral  blood sugar  \
# 577   77    1           4           125.0        304.0          0.0
# 144   76    0           3           140.0        197.0          0.0
# 129   74    0           2           120.0        269.0          0.0
# 25    71    0           2           160.0        302.0          0.0
# 60    71    0           3           110.0        265.0          1.0
#
#      electrocardiographic  heart rate  exercise induced  depression  slope ca  \
# 577                   2.0       162.0               1.0         0.0    1.0  3
# 144                   1.0       116.0               0.0         1.1    2.0  0
# 129                   2.0       121.0               1.0         0.2    1.0  1
# 25                    0.0       162.0               0.0         0.4    1.0  2
# 60                    2.0       130.0               0.0         0.0    1.0  1
#
#     thal
# 577    3
# 144    3
# 129    3
# 25     3
# 60     3

# %% [markdown]
# ### Renaming columns

# %%
df.rename(columns={'blood sugar':'sugar',
                    'depression':'depression lvl'}).head(2)
# Out:
#      age  sex  chest pain  blood pressure  cholestoral  sugar  \
# 577   77    1           4           125.0        304.0    0.0
# 144   76    0           3           140.0        197.0    0.0
#
#      electrocardiographic  heart rate  exercise induced  depression lvl  \
# 577                   2.0       162.0               1.0             0.0
# 144                   1.0       116.0               0.0             1.1
#
#      slope ca thal
# 577    1.0  3    3
# 144    2.0  0    3

# %% [markdown]
# ### Handling missing values

# %%
df.isnull().sum()
# Out:
# age                       0
# sex                       0
# chest pain                0
# blood pressure            1
# cholestoral              23
# blood sugar               8
# electrocardiographic      1
# heart rate                1
# exercise induced          1
# depression                0
# slope                   190
# ca                      290
# thal                    266
# dtype: int64

# %%
df.isna().sum()
# Out:
# age                       0
# sex                       0
# chest pain                0
# blood pressure            1
# cholestoral              23
# blood sugar               8
# electrocardiographic      1
# heart rate                1
# exercise induced          1
# depression                0
# slope                   190
# ca                      290
# thal                    266
# dtype: int64

# %%
df.isna().mean()*100.0
# Out:
# age                      0.000000
# sex                      0.000000
# chest pain               0.000000
# blood pressure           0.167504
# cholestoral              3.852596
# blood sugar              1.340034
# electrocardiographic     0.167504
# heart rate               0.167504
# exercise induced         0.167504
# depression               0.000000
# slope                   31.825796
# ca                      48.576214
# thal                    44.556114
# dtype: float64

# %% [markdown]
# #### Interpolating missing values

# %%
df_ = df.copy()

# %%
df_.fillna(-1, inplace=True)
df_.isna().sum()
# Out:
# age                     0
# sex                     0
# chest pain              0
# blood pressure          0
# cholestoral             0
# blood sugar             0
# electrocardiographic    0
# heart rate              0
# exercise induced        0
# depression              0
# slope                   0
# ca                      0
# thal                    0
# dtype: int64

# %%
del df_
gc.collect()
# Out:
# 68

# %% [markdown]
# #### Replacing missing values with mean

# %%
df_ = df.copy()
df_ = df_.fillna(df_.mean())

# %%
df_.isnull().sum()
# Out:
# age                       0
# sex                       0
# chest pain                0
# blood pressure            0
# cholestoral               0
# blood sugar               0
# electrocardiographic      0
# heart rate                0
# exercise induced          0
# depression                0
# slope                     0
# ca                      290
# thal                    266
# dtype: int64

# %%
df_[df_['thal'].isnull()]
# Out:
#      age  sex  chest pain  blood pressure  cholestoral  blood sugar  \
# 550   66    1           4           140.0   248.655052          0.0
# 413   65    1           4           140.0   306.000000          1.0
# 551   65    1           4           170.0   263.000000          1.0
# 584   65    1           4           130.0   275.000000          0.0
# 420   63    1           4           150.0   223.000000          0.0
# ..   ...  ...         ...             ...          ...          ...
# 295   31    0           2           100.0   219.000000          0.0
# 415   31    1           4           120.0   270.000000          0.0
# 271   29    1           2           120.0   243.000000          0.0
# 305   29    1           2           140.0   248.655052          0.0
# 299   28    1           2           130.0   132.000000          0.0
#
#      electrocardiographic  heart rate  exercise induced  depression     slope  \
# 550                   0.0        94.0               1.0         1.0  2.000000
# 413                   0.0        87.0               1.0         1.5  2.000000
# 551                   0.0       112.0               1.0         2.0  2.000000
# 584                   1.0       115.0               1.0         1.0  2.000000
# 420                   0.0       115.0               0.0         0.0  1.675676
# ..                    ...         ...               ...         ...       ...
# 295                   1.0       150.0               0.0         0.0  1.675676
# 415                   0.0       153.0               1.0         1.5  2.000000
# 271                   0.0       160.0               0.0         0.0  1.675676
# 305                   0.0       170.0               0.0         0.0  1.675676
# 299                   2.0       185.0               0.0         0.0  1.675676
#
#       ca thal
# 550  NaN  NaN
# 413  NaN  NaN
# 551  NaN  NaN
# 584  NaN  NaN
# 420  NaN  NaN
# ..   ...  ...
# 295  NaN  NaN
# 415  NaN  NaN
# 271  NaN  NaN
# 305  NaN  NaN
# 299  NaN  NaN
#
# [266 rows x 13 columns]

# %%
for col in df.columns:
    print(df[col].dtype)
# Out:
# int64
# int64
# int64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# object
# object

# %%
for col in df.columns:
    if(df[col].dtype):
        df[col] = df[col].apply(pd.to_numeric)

        
for col in df.columns:
    print(df[col].dtype)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "?"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-7ae4259092d3> in <module>
#       1 for col in df.columns:
#       2     if(df[col].dtype):
# ----> 3         df[col] = df[col].apply(pd.to_numeric)
#       4
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     150         coerce_numeric = errors not in ("ignore", "raise")
#     151         try:
# --> 152             values = lib.maybe_convert_numeric(
#     153                 values, set(), coerce_numeric=coerce_numeric
#     154             )
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "?" at position 0

# %%
df['ca'].value_counts()
# Out:
# 0    179
# 1     65
# 2     38
# 3     20
# ?      4
# 9      1
# Name: ca, dtype: int64

# %%
df['ca'].isnull().sum()
# Out:
# 290

# %%
179+65+38+20+4+1+290
# Out:
# 597

# %%
df_['thal'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-2ed661625ec9> in <module>
# ----> 1 df_['thal'].mean()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11466         if level is not None:
#   11467             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11468         return self._reduce(
#   11469             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11470         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4234                 )
#    4235             with np.errstate(all="ignore"):
# -> 4236                 return op(delegate, skipna=skipna, **kwds)
#    4237
#    4238     def _reindex_indexer(self, new_index, indexer, copy):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#      73                 # we want to transform an object array
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             else:
# --> 129                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     130
#     131             return result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     561         dtype_count = dtype
#     562     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 563     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     564
#     565     if axis is not None and getattr(the_sum, "ndim", False):
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
# ---> 47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      48
#      49 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
df[df['thal']=='?']
# Out:
#      age  sex  chest pain  blood pressure  cholestoral  blood sugar  \
# 48    53    0           3           128.0        216.0          0.0
# 471   52    1           4           128.0        204.0          1.0
#
#      electrocardiographic  heart rate  exercise induced  depression  slope ca  \
# 48                    2.0       115.0               0.0         0.0    1.0  0
# 471                   0.0       156.0               1.0         1.0    2.0  0
#
#     thal
# 48     ?
# 471    ?

# %%
df[df['thal']=='?'] = np.nan

# %%
df['ca'] .value_counts()
# Out:
# 0    177
# 1     65
# 2     38
# 3     20
# ?      4
# 9      1
# Name: ca, dtype: int64

# %%
df[df['ca']=='?'] = np.nan

# %%
df['ca'] = df['ca'].astype(float)
df['thal'] = df['thal'].astype(float)

# %%
df2 = df.copy()

# %%
df2.isna().sum()
# Out:
# age                       6
# sex                       6
# chest pain                6
# blood pressure            7
# cholestoral              29
# blood sugar              14
# electrocardiographic      7
# heart rate                7
# exercise induced          7
# depression                6
# slope                   196
# ca                      296
# thal                    272
# dtype: int64

# %% [markdown]
# ## HW: Replace each null value by the average of previous and next value!

# %%
for col in df.columns:
    print(df[col].dtype)
# Out:
# int64
# int64
# int64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# object
# object
# int64

# %%
df['thal'].value_counts()
# Out:
# 3    173
# 7    128
# 6     28
# ?      2
# Name: thal, dtype: int64

# %%
df[df['thal']=='?']=0

# %%
df['thal'].value_counts()
# Out:
# 3    173
# 7    128
# 6     28
# 0      2
# Name: thal, dtype: int64

# %%
df['ca'].value_counts()
# Out:
# 0    179
# 1     65
# 2     38
# 3     20
# ?      4
# 9      1
# Name: ca, dtype: int64

# %%
df[df['ca']=='?']=0

# %%
df['ca'].value_counts()
# Out:
# 0    183
# 1     65
# 2     38
# 3     20
# 9      1
# Name: ca, dtype: int64

# %%
df['thal'] = df['thal'].astype(float)

# %%
df['ca'] = df['ca'].astype(float) # ValueError: cannot convert float NaN to integer

# %%
import os
import pandas as pd
import numpy as np


fol = os.path.join(os.getcwd(), 'dataset')
file_to_read = os.path.join(os.path.join(os.getcwd(), 'dataset'), 'Heart data.xlsx')
df = pd.read_excel(file_to_read)

df[df['thal']=='?']=0
df[df['ca']=='?']=0
df['thal'] = df['thal'].astype(float)
df['ca'] = df['ca'].astype(float)

df2 = df.fillna( (df.fillna(method='ffill') + df.fillna(method='bfill') )/2 )

# %%
df2.isnull().sum()
# Out:
# age                      0
# sex                      0
# chest pain               0
# blood pressure           0
# cholestoral              0
# blood sugar              0
# electrocardiographic     0
# heart rate               0
# exercise induced         0
# depression               0
# slope                    0
# ca                      15
# thal                    11
# c                        0
# dtype: int64

# %%
df2.head()
# Out:
#    age  sex  chest pain  blood pressure  cholestoral  blood sugar  \
# 0   63    1           1           145.0        233.0          1.0
# 1   37    1           3           130.0        250.0          0.0
# 2   41    0           2           130.0        204.0          0.0
# 3   56    1           2           120.0        236.0          0.0
# 4   57    0           4           120.0        354.0          0.0
#
#    electrocardiographic  heart rate  exercise induced  depression  slope   ca  \
# 0                   2.0       150.0               0.0         2.3    3.0  0.0
# 1                   0.0       187.0               0.0         3.5    3.0  0.0
# 2                   2.0       172.0               0.0         1.4    1.0  0.0
# 3                   0.0       178.0               0.0         0.8    1.0  0.0
# 4                   0.0       163.0               1.0         0.6    1.0  0.0
#
#    thal  c
# 0   6.0  0
# 1   3.0  0
# 2   3.0  0
# 3   3.0  0
# 4   3.0  0

# %%
df2[df2['thal'].isnull()]
# Out:
#      age  sex  chest pain  blood pressure  cholestoral  blood sugar  \
# 586   52    1           4           160.0        331.0          0.0
# 587   50    1           4           140.0        341.0          0.0
# 588   47    1           4           160.0        291.0          0.0
# 589   56    1           4           155.0        342.0          1.0
# 590   49    1           4           128.0        212.0          0.0
# 591   50    1           4           140.0        231.0          0.0
# 592   52    1           4           140.0        266.0          0.0
# 593   43    1           4           140.0        288.0          0.0
# 594   41    1           4           120.0        336.0          0.0
# 595   44    1           4           135.0        491.0          0.0
# 596   49    1           4           150.0        222.0          0.0
#
#      electrocardiographic  heart rate  exercise induced  depression  slope  \
# 586                   0.0        94.0               1.0         2.5    2.0
# 587                   1.0       125.0               1.0         2.5    2.0
# 588                   1.0       158.0               1.0         3.0    2.0
# 589                   0.0       150.0               1.0         3.0    2.0
# 590                   0.0        96.0               1.0         0.0    2.0
# 591                   1.0       140.0               1.0         5.0    2.0
# 592                   0.0       134.0               1.0         2.0    2.0
# 593                   0.0       135.0               1.0         2.0    2.0
# 594                   0.0       118.0               1.0         3.0    2.0
# 595                   0.0       135.0               0.0         0.0    2.0
# 596                   0.0       122.0               0.0         2.0    2.0
#
#      ca  thal  c
# 586 NaN   NaN  1
# 587 NaN   NaN  1
# 588 NaN   NaN  1
# 589 NaN   NaN  1
# 590 NaN   NaN  1
# 591 NaN   NaN  1
# 592 NaN   NaN  1
# 593 NaN   NaN  1
# 594 NaN   NaN  1
# 595 NaN   NaN  1
# 596 NaN   NaN  1

# %%
df2[-16:]
# Out:
#      age  sex  chest pain  blood pressure  cholestoral  blood sugar  \
# 581   58    1           4           114.0        318.0          0.0
# 582   54    0           3           130.0        294.0          0.0
# 583   47    0           4           120.0        205.0          0.0
# 584   65    1           4           130.0        275.0          0.0
# 585   58    0           2           180.0        393.0          0.0
# 586   52    1           4           160.0        331.0          0.0
# 587   50    1           4           140.0        341.0          0.0
# 588   47    1           4           160.0        291.0          0.0
# 589   56    1           4           155.0        342.0          1.0
# 590   49    1           4           128.0        212.0          0.0
# 591   50    1           4           140.0        231.0          0.0
# 592   52    1           4           140.0        266.0          0.0
# 593   43    1           4           140.0        288.0          0.0
# 594   41    1           4           120.0        336.0          0.0
# 595   44    1           4           135.0        491.0          0.0
# 596   49    1           4           150.0        222.0          0.0
#
#      electrocardiographic  heart rate  exercise induced  depression  slope  \
# 581                   1.0       140.0               0.0         4.4    3.0
# 582                   1.0       100.0               1.0         0.0    2.0
# 583                   0.0        98.0               1.0         2.0    2.0
# 584                   1.0       115.0               1.0         1.0    2.0
# 585                   0.0       110.0               1.0         1.0    2.0
# 586                   0.0        94.0               1.0         2.5    2.0
# 587                   1.0       125.0               1.0         2.5    2.0
# 588                   1.0       158.0               1.0         3.0    2.0
# 589                   0.0       150.0               1.0         3.0    2.0
# 590                   0.0        96.0               1.0         0.0    2.0
# 591                   1.0       140.0               1.0         5.0    2.0
# 592                   0.0       134.0               1.0         2.0    2.0
# 593                   0.0       135.0               1.0         2.0    2.0
# 594                   0.0       118.0               1.0         3.0    2.0
# 595                   0.0       135.0               0.0         0.0    2.0
# 596                   0.0       122.0               0.0         2.0    2.0
#
#       ca  thal  c
# 581  3.0   6.0  1
# 582  NaN   6.0  1
# 583  NaN   6.0  1
# 584  NaN   6.5  1
# 585  NaN   7.0  1
# 586  NaN   NaN  1
# 587  NaN   NaN  1
# 588  NaN   NaN  1
# 589  NaN   NaN  1
# 590  NaN   NaN  1
# 591  NaN   NaN  1
# 592  NaN   NaN  1
# 593  NaN   NaN  1
# 594  NaN   NaN  1
# 595  NaN   NaN  1
# 596  NaN   NaN  1

# %%
df[-16:]
# Out:
#      age  sex  chest pain  blood pressure  cholestoral  blood sugar  \
# 581   58    1           4           114.0        318.0          0.0
# 582   54    0           3           130.0        294.0          0.0
# 583   47    0           4           120.0        205.0          0.0
# 584   65    1           4           130.0        275.0          0.0
# 585   58    0           2           180.0        393.0          0.0
# 586   52    1           4           160.0        331.0          0.0
# 587   50    1           4           140.0        341.0          0.0
# 588   47    1           4           160.0        291.0          0.0
# 589   56    1           4           155.0        342.0          1.0
# 590   49    1           4           128.0        212.0          0.0
# 591   50    1           4           140.0        231.0          0.0
# 592   52    1           4           140.0        266.0          0.0
# 593   43    1           4           140.0        288.0          0.0
# 594   41    1           4           120.0        336.0          0.0
# 595   44    1           4           135.0        491.0          0.0
# 596   49    1           4           150.0        222.0          0.0
#
#      electrocardiographic  heart rate  exercise induced  depression  slope  \
# 581                   1.0       140.0               0.0         4.4    3.0
# 582                   1.0       100.0               1.0         0.0    2.0
# 583                   0.0        98.0               1.0         2.0    2.0
# 584                   1.0       115.0               1.0         1.0    2.0
# 585                   0.0       110.0               1.0         1.0    2.0
# 586                   0.0        94.0               1.0         2.5    NaN
# 587                   1.0       125.0               1.0         2.5    2.0
# 588                   1.0       158.0               1.0         3.0    2.0
# 589                   0.0       150.0               1.0         3.0    2.0
# 590                   0.0        96.0               1.0         0.0    NaN
# 591                   1.0       140.0               1.0         5.0    2.0
# 592                   0.0       134.0               1.0         2.0    2.0
# 593                   0.0       135.0               1.0         2.0    2.0
# 594                   0.0       118.0               1.0         3.0    2.0
# 595                   0.0       135.0               0.0         0.0    NaN
# 596                   0.0       122.0               0.0         2.0    2.0
#
#       ca  thal  c
# 581  3.0   6.0  1
# 582  NaN   NaN  1
# 583  NaN   6.0  1
# 584  NaN   NaN  1
# 585  NaN   7.0  1
# 586  NaN   NaN  1
# 587  NaN   NaN  1
# 588  NaN   NaN  1
# 589  NaN   NaN  1
# 590  NaN   NaN  1
# 591  NaN   NaN  1
# 592  NaN   NaN  1
# 593  NaN   NaN  1
# 594  NaN   NaN  1
# 595  NaN   NaN  1
# 596  NaN   NaN  1

# %%
# for row in df2[df2.isna()]:
#     for col in df2.columns:
#         df2[col].fillna()

# %%
# for col in df2.columns:
#     df2[col].fillna()

# %% [markdown]
# ### Memberships

# %%
type(df['thal'])
# Out:
# pandas.core.series.Series

# %%
df['thal'].value_counts()
# Out:
# 3    173
# 7    128
# 6     28
# ?      2
# Name: thal, dtype: int64

# %%
df[df['thal'].isin([3])]
# Out:
#      age  sex  chest pain  blood pressure  cholestoral  blood sugar  \
# 577   77    1           4           125.0        304.0          0.0
# 144   76    0           3           140.0        197.0          0.0
# 129   74    0           2           120.0        269.0          0.0
# 25    71    0           2           160.0        302.0          0.0
# 60    71    0           3           110.0        265.0          1.0
# ..   ...  ...         ...             ...          ...          ...
# 157   35    1           2           122.0        192.0          0.0
# 65    35    0           4           138.0        183.0          0.0
# 58    34    1           1           118.0        182.0          0.0
# 125   34    0           2           118.0        210.0          0.0
# 72    29    1           2           130.0        204.0          0.0
#
#      electrocardiographic  heart rate  exercise induced  depression  slope ca  \
# 577                   2.0       162.0               1.0         0.0    1.0  3
# 144                   1.0       116.0               0.0         1.1    2.0  0
# 129                   2.0       121.0               1.0         0.2    1.0  1
# 25                    0.0       162.0               0.0         0.4    1.0  2
# 60                    2.0       130.0               0.0         0.0    1.0  1
# ..                    ...         ...               ...         ...    ... ..
# 157                   0.0       174.0               0.0         0.0    1.0  0
# 65                    0.0       182.0               0.0         1.4    1.0  0
# 58                    2.0       174.0               0.0         0.0    1.0  0
# 125                   0.0       192.0               0.0         0.7    1.0  0
# 72                    2.0       202.0               0.0         0.0    1.0  0
#
#     thal
# 577    3
# 144    3
# 129    3
# 25     3
# 60     3
# ..   ...
# 157    3
# 65     3
# 58     3
# 125    3
# 72     3
#
# [173 rows x 13 columns]
